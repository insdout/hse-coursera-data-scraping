# %% [markdown]
# # Playing with Encodings
#
# ## Week 1. Practice Programming Assignment 1
#
# In this assignment we will check, that everything is set up so coursera graders work fine in programming assignments, and will practice python encoding functions a bit.

# %% [markdown]
# ##### Import coursera grader tools

# %%
import sys
sys.path.append("..")
import grading
grader = grading.Grader(assignment_key="BWTScac0SDGglNs7aK8CLA", 
                      all_parts=["EsbZk", "j9e6W", "k2flq", "2kPZj", "RUDvM"])

# %%
# token expires every 30 min
COURSERA_EMAIL = ### YOUR EMAIL HERE
COURSERA_TOKEN = ### YOUR TOKEN

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ### Part 1. Number conversion

# %% [markdown]
# In this part you don't have to do anything but go through and submit an answer. Just checking that the grader works.
#
# <br><br>
# Let's look at a character 'h'.

# %%
# we can find its code point number in decimal system
ord('h')
# Out:
# 104

# %%
# we can convert it into a hexadicmal form
# remember, that '0x' is just a prefix, meaning that this is a hexadecimal form of a number
hex(104)
# Out:
# '0x68'

# %%
# or we can conver it back to decimal
int('68', 16)
# Out:
# 104

# %%
# we can convert it into a binary form
# remember, that '0b' is just a prefix, meaning that this is a binary form of a number
bin(104)
# Out:
# '0b1101000'

# %%
# or back again
int('1101000', 2)
# Out:
# 104

# %%
# and we can print any character by its code point
print('\x68')
print('\u0068')
print('\U00000068')
# Out:
# h
# h
# h

# %% [markdown]
# What is letter 'h' code point number in hexadecimal form?

# %%
answer_part_1 = 68

# %% [markdown]
# What is letter 'h' code point number in binary form?

# %%
answer_part_2 = 2

# %%
answer_part_2 = 1101000

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("EsbZk", answer_part_1)
grader.set_answer("j9e6W", answer_part_2)

# %%
# you can make submission with answers so far to check yourself at this stage
grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!

# %% [markdown]
# <br><br><br>
# ### Part 2. Decoding secret messages

# %% [markdown]
# In this part you are given several byte-strings. These are some messages encoded by some of the encodings covered in lectures. I suggest you to try different encodings to decode the messages until you will get some meaningful result. The results should be submited via grader.

# %% [markdown]
# <br>

# %%
secret_message_1 = b'\xff\xfeY\x00e\x00a\x00h\x00s\x00!\x00 \x00I\x00 '\
                   b'\x00d\x00e\x00c\x00o\x00d\x00e\x00d\x00 \x00t\x00h\x00e\x00 '\
                   b'\x00s\x00e\x00c\x00r\x00e\x00t\x00 \x00m\x00e\x00s\x00s\x00a'\
                   b'\x00g\x00e\x00'

# %%
import encodings, pprint
enc = sorted(encodings.aliases.aliases.values())
enc = set(enc)

# %%
for e in enc:
    try:
        print(e)
        print(secret_message_1.decode(e, errors="ignore"))
    except:
        continue
# Out:
# cp1252
# ÿþYeahs! I decoded the secret message
# iso2022_kr
# Yeahs! I decoded the secret message
# cp1254
# ÿşYeahs! I decoded the secret message
# cp775
#  ■Yeahs! I decoded the secret message
# iso8859_6
# Yeahs! I decoded the secret message
# cp850
#  ■Yeahs! I decoded the secret message
# iso8859_2
# ˙ţYeahs! I decoded the secret message
# iso8859_8
# ‏Yeahs! I decoded the secret message
# rot_13
# cp1258
# ÿ₫Yeahs! I decoded the secret message
# iso2022_jp_ext
# Yeahs! I decoded the secret message
# cp1125
#  ■Yeahs! I decoded the secret message
# iso8859_5
# џўYeahs! I decoded the secret message
# iso2022_jp_1
# Yeahs! I decoded the secret message
# koi8_r
# ЪЧYeahs! I decoded the secret message
# iso2022_jp_2004
# Yeahs! I decoded the secret message
# cp437
#  ■Yeahs! I decoded the secret message
# iso2022_jp
# Yeahs! I decoded the secret message
# iso8859_14
# ÿŷYeahs! I decoded the secret message
# iso8859_9
# ÿşYeahs! I decoded the secret message
# latin_1
# ÿþYeahs! I decoded the secret message
# utf_32_be
#
# tis_620
# Yeahs! I decoded the secret message
# cp1253
# ώYeahs! I decoded the secret message
# iso2022_jp_3
# Yeahs! I decoded the secret message
# utf_7
# Yeahs! I decoded the secret message
# iso8859_13
# ’žYeahs! I decoded the secret message
# cp1250
# ˙ţYeahs! I decoded the secret message
# ptcp154
# яюYeahs! I decoded the secret message
# cp500
# ÚßÁ/ÇËñÀÁÄ?ÀÁÀÈÇÁËÁÄÊÁÈ_ÁËË/ÅÁ
# cp861
#  ■Yeahs! I decoded the secret message
# ascii
# Yeahs! I decoded the secret message
# iso8859_3
# ˙ŝYeahs! I decoded the secret message
# big5
# Yeahs! I decoded the secret message
# cp852
#  ■Yeahs! I decoded the secret message
# base64_codec
# cp857
#  ■Yeahs! I decoded the secret message
# euc_jis_2004
# Yeahs! I decoded the secret message
# iso8859_11
# Yeahs! I decoded the secret message
# utf_16_be
# ￾夀攀愀栀猀℀ 䤀 搀攀挀漀搀攀搀 琀栀攀 猀攀挀爀攀琀 洀攀猀猀愀最攀
# mac_greek
# ­ΰYeahs! I decoded the secret message
# cp863
#  ■Yeahs! I decoded the secret message
# quopri_codec
# cp865
#  ■Yeahs! I decoded the secret message
# bz2_codec
# big5hkscs
# 献eahs! I decoded the secret message
# cp949
# Yeahs! I decoded the secret message
# mac_iceland
# ˇ˛Yeahs! I decoded the secret message
# mac_roman
# ˇ˛Yeahs! I decoded the secret message
# cp864
# ■Yeahs! I decoded the secret message
# cp424
# סץ/רטפץף?פץפ רץץףץ _ץ/קץ
# gb18030
# eahs! I decoded the secret message
# shift_jisx0213
# Yeahs! I decoded the secret message
# gbk
# Yeahs! I decoded the secret message
# zlib_codec
# cp862
#  ■Yeahs! I decoded the secret message
# tactis
# utf_16
# Yeahs! I decoded the secret message
# iso8859_4
# ˙ūYeahs! I decoded the secret message
# iso8859_10
# ĸþYeahs! I decoded the secret message
# cp866
#  ■Yeahs! I decoded the secret message
# mac_turkish
# ˇ˛Yeahs! I decoded the secret message
# iso8859_16
# ÿțYeahs! I decoded the secret message
# euc_kr
# Yeahs! I decoded the secret message
# utf_32
#
# cp1251
# яюYeahs! I decoded the secret message
# hex_codec
# euc_jp
# Yeahs! I decoded the secret message
# utf_16_le
# ﻿Yeahs! I decoded the secret message
# shift_jis_2004
# Yeahs! I decoded the secret message
# kz1048
# яюYeahs! I decoded the secret message
# utf_32_le
#
# cp860
#  ■Yeahs! I decoded the secret message
# shift_jis
# Yeahs! I decoded the secret message
# uu_codec
# cp1257
# ˙žYeahs! I decoded the secret message
# gb2312
# Yeahs! I decoded the secret message
# cp869
#  ■Yeahs! I decoded the secret message
# cp037
# ÚßÁ/ÇËñÀÁÄ?ÀÁÀÈÇÁËÁÄÊÁÈ_ÁËË/ÅÁ
# mac_cyrillic
# €юYeahs! I decoded the secret message
# euc_jisx0213
# Yeahs! I decoded the secret message
# iso8859_15
# ÿþYeahs! I decoded the secret message
# mbcs
# яюYeahs! I decoded the secret message
# cp932
# Yeahs! I decoded the secret message
# cp950
# Yeahs! I decoded the secret message
# cp1256
# ے‏Yeahs! I decoded the secret message
# cp1255
# ‏Yeahs! I decoded the secret message
# iso2022_jp_2
# Yeahs! I decoded the secret message
# mac_latin2
# ˇĢYeahs! I decoded the secret message
# iso8859_7
# ώYeahs! I decoded the secret message
# cp1140
# ÚßÁ/ÇËñÀÁÄ?ÀÁÀÈÇÁËÁÄÊÁÈ_ÁËË/ÅÁ
# cp855
#  ■Yeahs! I decoded the secret message
# johab
# Yeahs! I decoded the secret message
# hz
# Yeahs! I decoded the secret message
# utf_8
# Yeahs! I decoded the secret message
# cp273
# Ú~Á/ÇËñÀÁ[?ÀÁÀÈÇÁËÁ[ÊÁÈ_ÁËË/ÅÁ
# cp858
#  ■Yeahs! I decoded the secret message
# cp1026
# ÚßÁ/[ËñÀÁÄ?ÀÁÀÈ[ÁËÁÄÊÁÈ_ÁËË/ÅÁ
# hp_roman8
# ±Yeahs! I decoded the secret message

# %%
secret_message_1.decode("utf_16")
# Out:
# 'Yeahs! I decoded the secret message'

# %%
# put decoded message here
answer_part_3 = secret_message_1.decode("utf_16")

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("k2flq", answer_part_3)

# %%
# you can make submission with answers so far to check yourself at this stage
grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %% [markdown]
# <br>

# %%
secret_message_2 = b"\xff\xfe\x00\x00T\x00\x00\x00o\x00\x00\x00 "\
                   b"\x00\x00\x00d\x00\x00\x00e\x00\x00\x00c\x00"\
                   b"\x00\x00o\x00\x00\x00d\x00\x00\x00e\x00\x00"\
                   b"\x00 \x00\x00\x00t\x00\x00\x00h\x00\x00\x00e"\
                   b"\x00\x00\x00 \x00\x00\x00t\x00\x00\x00h\x00"\
                   b"\x00\x00i\x00\x00\x00r\x00\x00\x00d\x00\x00"\
                   b"\x00 \x00\x00\x00s\x00\x00\x00e\x00\x00\x00c"\
                   b"\x00\x00\x00r\x00\x00\x00e\x00\x00\x00t\x00\x00"\
                   b"\x00 \x00\x00\x00m\x00\x00\x00e\x00\x00\x00s\x00"\
                   b"\x00\x00s\x00\x00\x00a\x00\x00\x00g\x00\x00\x00e\x00"\
                   b"\x00\x00 \x00\x00\x00y\x00\x00\x00o\x00\x00\x00u\x00\x00"\
                   b"\x00 \x00\x00\x00s\x00\x00\x00h\x00\x00\x00o\x00\x00\x00u"\
                   b"\x00\x00\x00l\x00\x00\x00d\x00\x00\x00 \x00\x00\x00u\x00\x00"\
                   b"\x00s\x00\x00\x00e\x00\x00\x00 \x00\x00\x00'\x00\x00\x00s\x00"\
                   b"\x00\x00h\x00\x00\x00i\x00\x00\x00f\x00\x00\x00t\x00\x00"\
                   b"\x00_\x00\x00\x00j\x00\x00\x00i\x00\x00\x00s\x00\x00"\
                   b"\x00'\x00\x00\x00 \x00\x00\x00e\x00\x00\x00n\x00\x00\x00c\x00"\
                   b"\x00\x00o\x00\x00\x00d\x00\x00\x00i\x00\x00\x00n\x00\x00\x00g\x00\x00\x00"

# %%
for e in enc:
    try:
        print(e)
        print(secret_message_2.decode(e))
    except:
        continue
# Out:
# cp1252
# ÿþTo decode the third secret message you should use 'shift_jis' encoding
# iso2022_kr
# cp1254
# ÿşTo decode the third secret message you should use 'shift_jis' encoding
# cp775
#  ■To decode the third secret message you should use 'shift_jis' encoding
# iso8859_6
# cp850
#  ■To decode the third secret message you should use 'shift_jis' encoding
# iso8859_2
# ˙ţTo decode the third secret message you should use 'shift_jis' encoding
# iso8859_8
# rot_13
# cp1258
# ÿ₫To decode the third secret message you should use 'shift_jis' encoding
# iso2022_jp_ext
# cp1125
#  ■To decode the third secret message you should use 'shift_jis' encoding
# iso8859_5
# џўTo decode the third secret message you should use 'shift_jis' encoding
# iso2022_jp_1
# koi8_r
# ЪЧTo decode the third secret message you should use 'shift_jis' encoding
# iso2022_jp_2004
# cp437
#  ■To decode the third secret message you should use 'shift_jis' encoding
# iso2022_jp
# iso8859_14
# ÿŷTo decode the third secret message you should use 'shift_jis' encoding
# iso8859_9
# ÿşTo decode the third secret message you should use 'shift_jis' encoding
# latin_1
# ÿþTo decode the third secret message you should use 'shift_jis' encoding
# utf_32_be
# tis_620
# cp1253
# iso2022_jp_3
# utf_7
# iso8859_13
# ’žTo decode the third secret message you should use 'shift_jis' encoding
# cp1250
# ˙ţTo decode the third secret message you should use 'shift_jis' encoding
# ptcp154
# яюTo decode the third secret message you should use 'shift_jis' encoding
# cp500
# Úè?ÀÁÄ?ÀÁÈÇÁÈÇÑÊÀËÁÄÊÁÈ_ÁËË/ÅÁ`?ÍËÇ?Í%ÀÍËÁËÇÑÃÈ^¦ÑËÁ>Ä?ÀÑ>Å
# cp861
#  ■To decode the third secret message you should use 'shift_jis' encoding
# ascii
# iso8859_3
# ˙ŝTo decode the third secret message you should use 'shift_jis' encoding
# big5
# cp852
#  ■To decode the third secret message you should use 'shift_jis' encoding
# base64_codec
# cp857
#  ■To decode the third secret message you should use 'shift_jis' encoding
# euc_jis_2004
# iso8859_11
# utf_16_be
# ￾吀漀 搀攀挀漀搀攀 琀栀攀 琀栀椀爀搀 猀攀挀爀攀琀 洀攀猀猀愀最攀 礀漀甀 猀栀漀甀氀搀 甀猀攀 ✀猀栀椀昀琀开樀椀猀✀ 攀渀挀漀搀椀渀最
# mac_greek
# ­ΰTo decode the third secret message you should use 'shift_jis' encoding
# cp863
#  ■To decode the third secret message you should use 'shift_jis' encoding
# quopri_codec
# cp865
#  ■To decode the third secret message you should use 'shift_jis' encoding
# bz2_codec
# big5hkscs
# cp949
# mac_iceland
# ˇ˛To decode the third secret message you should use 'shift_jis' encoding
# mac_roman
# ˇ˛To decode the third secret message you should use 'shift_jis' encoding
# cp864
# cp424
# gb18030
# shift_jisx0213
# gbk
# zlib_codec
# cp862
#  ■To decode the third secret message you should use 'shift_jis' encoding
# tactis
# utf_16
# To decode the third secret message you should use 'shift_jis' encoding
# iso8859_4
# ˙ūTo decode the third secret message you should use 'shift_jis' encoding
# iso8859_10
# ĸþTo decode the third secret message you should use 'shift_jis' encoding
# cp866
#  ■To decode the third secret message you should use 'shift_jis' encoding
# mac_turkish
# ˇ˛To decode the third secret message you should use 'shift_jis' encoding
# iso8859_16
# ÿțTo decode the third secret message you should use 'shift_jis' encoding
# euc_kr
# utf_32
# To decode the third secret message you should use 'shift_jis' encoding
# cp1251
# яюTo decode the third secret message you should use 'shift_jis' encoding
# hex_codec
# euc_jp
# utf_16_le
# ﻿To decode the third secret message you should use 'shift_jis' encoding
# shift_jis_2004
# kz1048
# яюTo decode the third secret message you should use 'shift_jis' encoding
# utf_32_le
# ﻿To decode the third secret message you should use 'shift_jis' encoding
# cp860
#  ■To decode the third secret message you should use 'shift_jis' encoding
# shift_jis
# uu_codec
# cp1257
# ˙žTo decode the third secret message you should use 'shift_jis' encoding
# gb2312
# cp869
#  ■To decode the third secret message you should use 'shift_jis' encoding
# cp037
# Úè?ÀÁÄ?ÀÁÈÇÁÈÇÑÊÀËÁÄÊÁÈ_ÁËË/ÅÁ`?ÍËÇ?Í%ÀÍËÁËÇÑÃÈ¬¦ÑËÁ>Ä?ÀÑ>Å
# mac_cyrillic
# €юTo decode the third secret message you should use 'shift_jis' encoding
# euc_jisx0213
# iso8859_15
# ÿþTo decode the third secret message you should use 'shift_jis' encoding
# mbcs
# яюTo decode the third secret message you should use 'shift_jis' encoding
# cp932
# To decode the third secret message you should use 'shift_jis' encoding
# cp950
# cp1256
# ے‏To decode the third secret message you should use 'shift_jis' encoding
# cp1255
# iso2022_jp_2
# mac_latin2
# ˇĢTo decode the third secret message you should use 'shift_jis' encoding
# iso8859_7
# cp1140
# Úè?ÀÁÄ?ÀÁÈÇÁÈÇÑÊÀËÁÄÊÁÈ_ÁËË/ÅÁ`?ÍËÇ?Í%ÀÍËÁËÇÑÃÈ¬¦ÑËÁ>Ä?ÀÑ>Å
# cp855
#  ■To decode the third secret message you should use 'shift_jis' encoding
# johab
# hz
# utf_8
# cp273
# Úè?ÀÁ[?ÀÁÈÇÁÈÇÑÊÀËÁ[ÊÁÈ_ÁËË/ÅÁ`?ÍËÇ?Í%ÀÍËÁËÇÑÃÈ^öÑËÁ>[?ÀÑ>Å
# cp858
#  ■To decode the third secret message you should use 'shift_jis' encoding
# cp1026
# Úè?ÀÁÄ?ÀÁÈ[ÁÈ[ÑÊÀËÁÄÊÁÈ_ÁËË/ÅÁı?ÍË[?Í%ÀÍËÁË[ÑÃÈ^şÑËÁ>Ä?ÀÑ>Å
# hp_roman8

# %%
secret_message_2.decode("utf_32")
# Out:
# "To decode the third secret message you should use 'shift_jis' encoding"

# %%
# put decoded message here
answer_part_4 = secret_message_2.decode("utf_32")

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("2kPZj", answer_part_4)

# %%
# you can make submission with answers so far to check yourself at this stage
grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %% [markdown]
# <br>

# %%
secret_message_3 = b'\x83n\x83\x8d\x81[\x83\x8f\x81[\x83\x8b\x83h'

# %%
secret_message_3.decode('shift_jis')
# Out:
# 'ハローワールド'

# %%
# put decoded message here
answer_part_5 = secret_message_3.decode('shift_jis')

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("RUDvM", answer_part_5)

# %%
# you can make submission with answers so far to check yourself at this stage
grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!
